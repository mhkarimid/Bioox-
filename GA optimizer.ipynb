# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model
from keras.models import load_model
import random
import urllib.request
import os

# %%
url = "https://raw.githubusercontent.com/mhkarimid/Bioox-/main/my_model.h5"
filename = os.path.basename(url)

model= load_model(urllib.request.urlretrieve(url, filename)[0])

# %%
def f(x1,x2,x3,x4,x5,x6,x7,x8):
    INPUT=[[x1,x2,x3,x4,x5,x6,x7,x8]]
    A=model.predict(INPUT, verbose=0)
    return A

# %%
def fitness(x1,x2,x3,x4,x5,x6,x7,x8):
    ans1=1/f(x1,x2,x3,x4,x5,x6,x7,x8).tolist()[0][0]
    
    if  ans1==0:
        return  10000000000
    else: 
        return abs(1/ans1)

# %%
solutions=[]
for s in range(100):
    solutions.append((random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1), 
                     random.uniform(-1,1)))

# %%
for i in range(10000):
    rankedsolutions=[]
    for s in solutions:
        rankedsolutions.append((fitness(s[0],s[1],s[2],s[3],s[4],s[5],s[6],s[7]),s))
    rankedsolutions.sort()
    rankedsolutions.reverse()
    print(f"=== Gen {i} best solutions === ")
    print(rankedsolutions[0])
    bestsolutions=rankedsolutions[:15]
    
    elements=[]
    for s in bestsolutions:
        elements.append(s[1][0])
        elements.append(s[1][1])
        elements.append(s[1][2])
        elements.append(s[1][3])
        elements.append(s[1][4])
        elements.append(s[1][5])
        elements.append(s[1][6])
        elements.append(s[1][7])
    
    newGen=[]
    for _ in range(50):
        e1=random.choice(elements)*random.uniform(0.99,1.01)
        e2=random.choice(elements)*random.uniform(0.99,1.01)
        e3=random.choice(elements)*random.uniform(0.99,1.01)
        e4=random.choice(elements)*random.uniform(0.99,1.01)
        e5=random.choice(elements)*random.uniform(0.99,1.01)
        e6=random.choice(elements)*random.uniform(0.99,1.01)
        e7=random.choice(elements)*random.uniform(0.99,1.01)
        e8=random.choice(elements)*random.uniform(0.99,1.01)
        newGen.append((e1,e2,e3,e4,e5,e6,e7,e8))
        
        solutions=newGen
# Out:
# === Gen 0 best solutions ===
# (0.828628420829773, (0.7484732814418962, 0.6041384917532708, -0.3670189086601492, -0.21616374597234556, 0.7340101610363956, -0.9588917591758868, 0.798773571026959, 0.5785900998633489))
# === Gen 1 best solutions ===
# (0.8436086177825927, (0.9196665236185458, 0.84484978779633, -0.008219716567622347, 0.786101004974014, 0.5370524412889414, -0.6922997401086133, 0.675189899739333, -0.8968972255011952))
# === Gen 2 best solutions ===
# (0.932595193386078, (0.6277135736698423, 0.9340813392443227, 0.050424690360156496, 0.9711391215990255, 0.8124056528197504, -0.03316422421526237, 0.48461976713686017, 0.9688134177069921))
# === Gen 3 best solutions ===
# (0.8871321678161621, (0.18151721048173186, 0.9379544557647591, 0.8003061330989715, 0.21280943926763446, 0.9748475069908017, -0.2123674101258222, 0.04998290511764685, 0.05081463757107855))
# === Gen 4 best solutions ===
# (0.9590593576431274, (0.21130993542068197, 0.9592325150639708, -0.4280734426800702, -0.2108007677380145, 0.9602502067510531, 0.7280314232300918, 0.5798168055211833, -0.12720752867585305))
# === Gen 5 best solutions ===
# (0.9798001050949097, (0.8631973162356961, -0.42682029406470623, -0.42546254247877957, 0.9193838812252995, 0.9304650296244162, 0.8528102790599271, 0.2123643118775333, 0.18876832763809967))
# === Gen 6 best solutions ===
# (0.9676018953323364, (0.6033542386329219, -0.12666543013167356, -0.08823263230038712, 0.9763773300745171, 0.8330950739935328, -0.008330169518151789, 0.8798116764623083, 0.9487059788733718))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11268\1847554826.py in <module>
#       2     rankedsolutions=[]
#       3     for s in solutions:
# ----> 4         rankedsolutions.append((fitness(s[0],s[1],s[2],s[3],s[4],s[5],s[6],s[7]),s))
#       5     rankedsolutions.sort()
#       6     rankedsolutions.reverse()
#
# ~\AppData\Local\Temp\ipykernel_11268\4197702618.py in fitness(x1, x2, x3, x4, x5, x6, x7, x8)
#       1 def fitness(x1,x2,x3,x4,x5,x6,x7,x8):
# ----> 2     ans1=1/f(x1,x2,x3,x4,x5,x6,x7,x8).tolist()[0][0]
#       3
#       4     if  ans1==0:
#       5         return  10000000000
#
# ~\AppData\Local\Temp\ipykernel_11268\1459955235.py in f(x1, x2, x3, x4, x5, x6, x7, x8)
#       1 def f(x1,x2,x3,x4,x5,x6,x7,x8):
#       2     INPUT=[[x1,x2,x3,x4,x5,x6,x7,x8]]
# ----> 3     A=model.predict(INPUT, verbose=0)
#       4     return A
#
# D:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\ANACONDA\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2315                     )
#    2316
# -> 2317             data_handler = data_adapter.get_data_handler(
#    2318                 x=x,
#    2319                 batch_size=batch_size,
#
# D:\ANACONDA\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1577     if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579     return DataHandler(*args, **kwargs)
#    1580
#    1581
#
# D:\ANACONDA\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257
#    1258         adapter_cls = select_data_adapter(x, y)
# -> 1259         self._adapter = adapter_cls(
#    1260             x,
#    1261             y,
#
# D:\ANACONDA\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, shuffle, **kwargs)
#     712         )
#     713
# --> 714         self._internal_adapter = TensorLikeDataAdapter(
#     715             x,
#     716             y=y,
#
# D:\ANACONDA\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     343             return flat_dataset
#     344
# --> 345         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     346
#     347         dataset = self.slice_inputs(indices_dataset, inputs)
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func, name)
#    2335       A new `Dataset` with the transformation applied as described above.
#    2336     """
# -> 2337     return FlatMapDataset(self, map_func, name=name)
#    2338
#    2339   def ignore_errors(self, log_warning=False, name=None):
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5581     """See `Dataset.flat_map()` for details."""
#    5582     self._input_dataset = input_dataset
# -> 5583     self._map_func = structured_function.StructuredFunctionWrapper(
#    5584         map_func, self._transformation_name(), dataset=input_dataset)
#    5585     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\data\ops\structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     261         fn_factory = trace_tf_function(defun_kwargs)
#     262
# --> 263     self._function = fn_factory()
#     264     # There is no graph to add in eager mode.
#     265     add_to_graph &= not context.executing_eagerly()
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in get_concrete_function(self, *args, **kwargs)
#     224         `tf.Tensor` or `tf.TensorSpec`.
#     225     """
# --> 226     concrete_function = self._get_concrete_function_garbage_collected(
#     227         *args, **kwargs)
#     228     concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#     190
#     191     with self._lock:
# --> 192       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193       seen_names = set()
#     194       captured = object_identity.ObjectIdentitySet(
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     155       kwargs = {}
#     156
# --> 157     return self._maybe_define_function(args, kwargs)
#     158
#     159   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     358             args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
#     359
# --> 360           concrete_function = self._create_concrete_function(args, kwargs)
#     361
#     362           graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _create_concrete_function(self, args, kwargs)
#     282     arg_names = base_arg_names + missing_arg_names
#     283     concrete_function = monomorphic_function.ConcreteFunction(
# --> 284         func_graph_module.func_graph_from_py_func(
#     285             self._name,
#     286             self._python_function,
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1281         _, original_func = tf_decorator.unwrap(python_func)
#    1282
# -> 1283       func_outputs = python_func(*func_args, **func_kwargs)
#    1284
#    1285       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\data\ops\structured_function.py in wrapped_fn(*args)
#     238           attributes=defun_kwargs)
#     239       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 240         ret = wrapper_helper(*args)
#     241         ret = structure.to_tensor_list(self._output_structure, ret)
#     242         return [ops.convert_to_tensor(t) for t in ret]
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\data\ops\structured_function.py in wrapper_helper(*args)
#     169       if not _should_unpack(nested_args):
#     170         nested_args = (nested_args,)
# --> 171       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     172       ret = variable_utils.convert_variables_to_tensors(ret)
#     173       if _should_pack(ret):
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# D:\ANACONDA\lib\site-packages\keras\engine\data_adapter.py in slice_batch_indices(indices)
#     324             """
#     325             num_in_full_batch = num_full_batches * batch_size
# --> 326             first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     327             first_k_indices = tf.reshape(
#     328                 first_k_indices, [num_full_batches, batch_size]
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\ops\array_ops.py in slice(input_, begin, size, name)
#    1161     A `Tensor` the same type as `input_`.
#    1162   """
# -> 1163   return gen_array_ops._slice(input_, begin, size, name=name)
#    1164
#    1165
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in _slice(input, begin, size, name)
#   11913       pass  # Add nodes to the TensorFlow graph.
#   11914   # Add nodes to the TensorFlow graph.
# > 11915   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   11916         "Slice", input=input, begin=begin, size=size, name=name)
#   11917   _result = _outputs[:]
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     793       # Add Op to graph
#     794       # pylint: disable=protected-access
# --> 795       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     796                                  name=scope, input_types=input_types,
#     797                                  attrs=attr_protos, op_def=op_def)
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     747       inp = self.capture(inp)
#     748       captured_inputs.append(inp)
# --> 749     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     750         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     751         compute_device)
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3796     # Session.run call cannot occur between creating and mutating the op.
#    3797     with self._mutation_lock():
# -> 3798       ret = Operation(
#    3799           node_def,
#    3800           self,
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\ops.py in __init__(***failed resolving arguments***)
#    2105     # Initialize c_op from node_def and other inputs
#    2106     c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
# -> 2107     self._init_from_c_op(c_op=c_op, g=g)
#    2108
#    2109     self._original_op = original_op
#
# D:\ANACONDA\lib\site-packages\tensorflow\python\framework\ops.py in _init_from_c_op(self, c_op, g)
#    2175
#    2176     # Initialize self._outputs.
# -> 2177     num_outputs = pywrap_tf_session.TF_OperationNumOutputs(self._c_op)
#    2178     self._outputs = []
#    2179     for i in range(num_outputs):
#
# KeyboardInterrupt:
